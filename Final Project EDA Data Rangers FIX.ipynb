# %% [markdown]
# # **Belarus Used Cars**
#
# **Data Rangers**

# %% [markdown]
# Final project purwadhika.
#
# Mengelola dan membuat pemodelan dari data yang sudah diberikan, data yang akan digunakan adalah data Used Cars in Belarus.
#
# sumber data : [UsedCarsBelarus](https://www.kaggle.com/datasets/slavapasedko/belarus-used-cars-prices)

# %% [markdown]
# ### **Contents**
#
# 1. Business Problem Understanding
# 2. Data Understanding
# 3. Data Wrangling
# 4. EDA
# 5. Data Preprocessing
# 6. Modeling
# 7. Conclusion
# 8. Recommendation

# %% [markdown]
# ## **Business Problem Understanding**

# %% [markdown]
# **Context**
#
# Kami adalah sebuah startup yang bergerak dalam bidang penjualan mobil bekas yang berada di Belarus. Dengan teknologi yang sudah maju, tentunya kami memasarkan produk (dalam hal ini mobil bekas) melalui internet atau online. Dan pada Dewasa ini, moda transportasi sangat dibutuhkan oleh semua kalangan, mulai dari transportasi umum hingga kendaraan pribadi. Alasan yang paling mendasar adalah untuk kebutuhan mobilitas. Namun dari semua jenis moda transportasi, kendaraan bermotor seperti mobil adalah jenis moda transportasi yang memiliki permintaan tinggi dan banyak dari kalangan menengah keatas yang mempunyai permintaan tinggi terhadap kebutuhan mobil pribadi sebagai moda transportasi karena alasan fleksibilitas.
#
# Namun harga beli mobil baru menjadi permasalahan setiap individu karena mempunyai harga yang relatif tinggi serta memiliki depresiasi harga yang besar untuk setiap tahunnya meskipun fitur yang dimiliki hampir sama dengan keluaran terbarunya, oleh karena itu banyak permintaan atau peminat akan mobil bekas yang memiliki kondisi masih bagus untuk dijadikan pilihan sebagai kendaraan pribadi dari berbagai alasan tersebut, peluang bisnis pun muncul sehingga banyak para penyedia jasa layanan jual beli mobil bekas, mulai dari pedagang mobil, makelar mobil/broker hingga ke perusahaan yang menyediakan layanan platform jual beli mobil bekas seperti kami dan seiring berjalannya waktu mereka memasarkan produknya (mobil bekas) secara online.
#
# Dari banyaknya layanan jual beli mobil bekas yang akan memasarkan setiap unit mobil yang dimiliki ke bursa pasar secara online, tentunya kami membutuhkan sebuah keputusan untuk dapat menentukan harga beli mobil yang efisien sehingga mampu untuk menentukan harga jual yang kompetitif juga atau dalam artian memberikan harga yang ideal sesuai dengan kondisi mobil sehingga dapat menarik calon pembeli serta perusahaan membutuhkan analisa mengenai stok yang sudah dimiliki agar kedepannya sesuai dengan permintaan bursa pasar mobil bekas.

# %% [markdown]
# ## **Project User**

# %% [markdown]
# Didalam pengerjaan proyek ini, kami membuat sebuah pemodelan untuk memproyeksikan harga jual dari masing-masing unit mobil bekas yang sesuai dengan kondisi nya, maka dari itu hasil dari pemodelan yang akan kami buat nantinya akan digunakan oleh perusahaan sebagai berikut :
# - Divisi pengadaan barang

# %% [markdown]
# ## **Business Process**

# %% [markdown]
# **Bisnis Proses**
# Pada pengerjaan proyek ini, kami akan menjelaskan mengenai alur dari proses bisnsi perusahaan dalam penjualan mobil bekas.
#
# ![image.png](attachment:b87456c5-b22a-444e-aeee-bdde14a87e17.png)

# %% [markdown]
# ## **Problem Statement**
#
# Kami sebagai startup yang bergerak dalam bidang jual beli mobil bekas di Belarus, kami mendapatkan tantangan terbesar yaitu pemecahan masalah untuk dapat memiliki model bisnis yang menguntungkan secara finansial bagi perusahaan kami.
#
# Dalam pembelian harga mobil bekas untuk dijadikan pasokan stok di perusahaan, kami belum memiliki acuan dalam menentukan harga beli, sehingga kami harus merekrut pegawai yang ahli dalam bidang menentukan harga beli, namun hal tersebut akan membutuhkan biaya operasional yang tinggi sehingga kami membutuhkan metode lain untuk efisiensi pengeluaran dalam hal penentuan harga beli.
#
# Dalam hal ini penentuan harga beli sangat penting karena akan berpengaruh terhadap harga jual yang akan ditentukan oleh tim sales penjualan, sehingga perusahaan akan mendapatkan profit yang maksimal dalam melakukan transaksi bisnisnya. **Dengan bertambahnya layanan jual beli mobil yang ada, untuk menentukan harga jual yang tepat untuk dapat tetap kompetitif sangatlah bergantung pada harga beli yang dilakukan oleh perusahaan**.

# %% [markdown]
# ## **Goals**

# %% [markdown]
# Berdasarkan permasalahan tersebut, tim pengadaan barang di perusahaan dapat **menentukan harga beli yang tepat untuk tiap unit mobil** serta **melakukan efisiensi dari proses penentuan `harga beli` yang dilakukan oleh pegawai yang ahli dalam bidang penentan harga beli menjadi machine learning agar tidak mengeluarkan biaya opersional yang tinggi.** Sehingga apabila jumlah stok mobil yang akan dibeli semakin banyak, perusahaan akan menghemat biaya pengeluaran.
# **Dan kita dapat menentukan pemebelian stok mobil yang sesuai dengan jenis mobil yang diminati di Belarus.**

# %% [markdown]
# ## **Business Question**

# %% [markdown]
# Dalam pengerjaan proyek ini, ada beberapa business question yang akan kami tangani, yaitu :
#
# **Business Question For EDA**
#
# 1. Stok produsen mobil dengan jumlah tertinggi (10 teratas).
# 2. Berapa median harga di pasaran dari brand yang ingin kita beli?
# 3. Bagaimana pengaruh kondisi mobil terhadap harga beli?
# 4. Bagaimana pengaruh tahun produksi terhadap harga jual mobil?
# 5. Bagaimana pengaruh jenis bahan bakar terhadap harga jual mobil?
# 6. Bagaimana pengaruh jenis transmisi terhadap harga jual mobil?
# 7. Berapa jumlah stok di pasar berdasarkan warna mobil?
# 8. Bagaimana sebaran harga stok di pasar berdasarkan warna mobil?
#
# **Business Question For For Machine Learning**
# - Bagaimana proyeksi dari model yang telah dibuat dan pengaruhnya terhadap perusahaan?
# - Kapan machine learning akan digunakan?

# %% [markdown]
# **Analytics Approach**

# %% [markdown]
# Jadi, yang perlu kami lakukan adalah menganalisis data untuk dapat menemukan pola dari fitur-fitur yang ada, yang membedakan tipe unit mobil dengan tipe yang lainnya.
#
# Selanjutnya, kami akan membangun suatu model regresi yang akan membantu tim pengadaan barang dari layanan jual beli mobil untuk dapat menyediakan 'metode' untuk memprediksi harga beli yang ideal yaitu `machine learning`, yang mana akan berguna untuk tim pengadaan barang (mobil) untuk menentukan harga beli mobil.

# %% [markdown]
# **Project Limitation**

# %% [markdown]
# Pada pengerjaan proyek ini, kami melakukan beberapa batasan yang akan kami jadikan sebagai project limitation, seperti :
# 1. Menghapus feature segment (karena dalam dokumentasi dr sumber dataset nya, dalam mendapatkan data nya secara manual, sehingga tingkat kebenarannya diragukan)
# 2. Tidak menggunakan unique columns condition berjenis "for parts", karna kami melakukan proyeksi harga jual unit mobil
# 3. Tidak memasukan mobil dengan tahun produksi dibawah tahun 1980
# 4. Tidak menggunakan unique columns fuel type berjenis "electrocar" karena pada jenis mobil tersebut memang tidak ada volume kubikasi mobil (CC nya), sehingga terdapat missing value di jenis kolom volume(cm3) pada jenis mobil tersebut, sehingga untuk mengisi missing value pada volume(cm3) atau cc nya tidak bisa.
# 5. Model digunakan untuk memprediksi harga mobil hingga 5400 USD.

# %% [markdown]
# **Matrix Evaluation**

# %% [markdown]
# Evaluasi metrik yang akan digunakan adalah RMSE, MSE, dan MAE, di mana RMSE adalah nilai rataan akar kuadrat dari error, MSE adalah selisih antara nilai target output dengan nilai actual output, MAE adalah rataan nilai absolut dari error yang dihasilkan oleh model regresi. Semakin kecil nilai RMSE, MAE, yang dihasilkan, berarti model semakin akurat dalam memprediksi harga jual sesuai dengan limitasi fitur yang digunakan.

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# **Load Data**

# %%
df = pd.read_csv('cars.csv')
df.head()
# Out:
#     make model  priceUSD  year     condition  mileage(kilometers) fuel_type  \
# 0  mazda     2      5500  2008  with mileage             162000.0    petrol
# 1  mazda     2      5350  2009  with mileage             120000.0    petrol
# 2  mazda     2      7000  2009  with mileage              61000.0    petrol
# 3  mazda     2      3300  2003  with mileage             265000.0    diesel
# 4  mazda     2      5200  2008  with mileage              97183.0    diesel
#
#    volume(cm3)     color transmission         drive_unit segment
# 0       1500.0  burgundy    mechanics  front-wheel drive       B
# 1       1300.0     black    mechanics  front-wheel drive       B
# 2       1500.0    silver         auto  front-wheel drive       B
# 3       1400.0     white    mechanics  front-wheel drive       B
# 4       1400.0      gray    mechanics  front-wheel drive       B

# %% [markdown]
# Untuk melakukan analisa data, kami akan melakukan duplikasi dataframe (copy), hal ini akan kami lakukan agar tidak merubah data asli yang mana nanti akan berpengaruh kepada data preprocessing.

# %% [markdown]
# #### **Project Limitation For EDA**

# %% [markdown]
# **Duplikasi Dataframe**

# %%
df_c = df
df_c.head()
# Out:
#     make model  priceUSD  year     condition  mileage(kilometers) fuel_type  \
# 0  mazda     2      5500  2008  with mileage             162000.0    petrol
# 1  mazda     2      5350  2009  with mileage             120000.0    petrol
# 2  mazda     2      7000  2009  with mileage              61000.0    petrol
# 3  mazda     2      3300  2003  with mileage             265000.0    diesel
# 4  mazda     2      5200  2008  with mileage              97183.0    diesel
#
#    volume(cm3)     color transmission         drive_unit segment
# 0       1500.0  burgundy    mechanics  front-wheel drive       B
# 1       1300.0     black    mechanics  front-wheel drive       B
# 2       1500.0    silver         auto  front-wheel drive       B
# 3       1400.0     white    mechanics  front-wheel drive       B
# 4       1400.0      gray    mechanics  front-wheel drive       B

# %% [markdown]
# **Deskripsi Isi Data**
#
# Berikut adalah deskripsi dari isi data yang akan di analisa
#
#
# | **Attribute** | **Description** |
# | --- | --- |
# | make | Machine Firm |
# | model | Model of car |
# | priceUSD | Price in USD |
# | year | Production Year |
# | condition | Represents the condition at the sale moment |
# | mileage(kilometers) | Mileage in kilometers |
# | fuel_type | Type of the fuel (electro, petrol, diesel) |
# | volume(cm3) | Volume of the engine |
# | color | Color of Car |
# | transmission | Transmission of Car |
# | drive_unit | Type of drive unit |
# | segment | segment (this feature was collected manually, so it could be wrong) |
#
# <br>

# %%
df_c.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56244 entries, 0 to 56243
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   make                 56244 non-null  object
#  1   model                56244 non-null  object
#  2   priceUSD             56244 non-null  int64
#  3   year                 56244 non-null  int64
#  4   condition            56244 non-null  object
#  5   mileage(kilometers)  56244 non-null  float64
#  6   fuel_type            56244 non-null  object
#  7   volume(cm3)          56197 non-null  float64
#  8   color                56244 non-null  object
#  9   transmission         56244 non-null  object
#  10  drive_unit           54339 non-null  object
#  11  segment              50953 non-null  object
# dtypes: float64(2), int64(2), object(8)
# memory usage: 5.1+ MB

# %% [markdown]
# Dari Info tabel di atas, terlihat bahwa secara keseluruhan terdapat 56244 baris data dengan total 12 kolom. Setiap kolomnya memiliki tipe data yang berbeda-beda, yaitu object dan integer. Jika melihat dari informasi di atas didapati bahwa terdapat beberapa kolom yang memiliki missing value yaitu `volume(cm3)`,`drive_unit`,dan `segment`, sehingga perlu dilakukan pengecekan missing value.

# %% [markdown]
# **Cek Missing Value**

# %% [markdown]
# Untuk membuktikan bahwa terdapat `missing value` kita perlu melakukan pengecekan terhadap `missing value`

# %%
plt.figure(figsize = (15,20))
sns.heatmap(df_c.isna(), cmap = 'Reds_r',yticklabels = False, cbar= False)
plt.show()

# %%
df_c.isna().sum()
# Out:
# make                      0
# model                     0
# priceUSD                  0
# year                      0
# condition                 0
# mileage(kilometers)       0
# fuel_type                 0
# volume(cm3)              47
# color                     0
# transmission              0
# drive_unit             1905
# segment                5291
# dtype: int64

# %% [markdown]
# Dari Pengecekan Missing Value di atas, terlihat bahwa terdapat missing value pada 3 kolom yaitu:
# - volume(cm3) : 47
# - drive_unit : 1905
# - segment : 5291
#
# Dikarenakan terdapat missing value maka diperlukan project limitasi untuk mendapatkan hasil yang lebih sesuai.

# %% [markdown]
# **Menghapus data yang tidak digunakan**
#
# Langkah awal yang kami lakukan yaitu men-drop kolom segment karena terdapat banyak missing value dan data tersebut merupakan data yang perlu diisi dengan *data yang real* karena pada sumber dataset kami mendapatkan dokumentasi bahwa kolom `segment` tersebut dalam pengumpulan datanya dilakukan secara manual, sehingga tingkat akurasi kebenarannya diragukan.

# %%
df_c.drop(columns = ['segment'], inplace=True)

# %% [markdown]
# Kemudian karena kami hanya akan berfokus pada stok mobil yang mempunyai jenis bahan bakar `petrol` & `diesel` saja dan kami fokus pada analisa terhadap harga jual mobil maka kami tidak memasukan data yang memiliki unique berupa `for parts` yang terdapat pada kolom `condition` dan unique `electrocar` pada kolom `fuel_type`.

# %%
## Handling Fitur Condition
df_c['condition'].unique()
# Out:
# array(['with mileage', 'with damage', 'for parts'], dtype=object)

# %%
df_c= df_c[(df_c['condition'] == 'with mileage') | (df_c['condition'] == 'with damage')]

# %% [markdown]
# Setelah tidak memasukan jenis `for parts` kita perlu melakukan pengecekan kembali untuk unique pada kolom `condition`

# %%
df_c['condition'].unique()
# Out:
# array(['with mileage', 'with damage'], dtype=object)

# %%
## Handling Fitur Fuel_type
df_c['fuel_type'].unique()
# Out:
# array(['petrol', 'diesel', 'electrocar'], dtype=object)

# %%
df_c= df_c[(df_c['fuel_type'] == 'petrol') | (df_c['fuel_type'] == 'diesel')]

# %%
df_c['fuel_type'].unique()
# Out:
# array(['petrol', 'diesel'], dtype=object)

# %% [markdown]
# **Cek Duplikat**
#
# Langkah selanjutnya adalah kami akan melakukan pengecekan terhadap duplikasi data

# %%
df_c[df_c.duplicated()]
# Out:
#           make   model  priceUSD  year     condition  mileage(kilometers)  \
# 1930      audi     100      1280  1991  with mileage             305000.0
# 2054      audi     100      2000  1988  with mileage             350000.0
# 2140      audi     100      1100  1989  with mileage             350000.0
# 2179   peugeot     106       700  2000  with mileage              27000.0
# 4334   peugeot     406      2200  1995  with mileage             330000.0
# ...        ...     ...       ...   ...           ...                  ...
# 53694      bmw      x5     16500  2007  with mileage             265000.0
# 53828      bmw      x5     10000  2005  with mileage             231000.0
# 54264  citroen  xantia      1800  1999  with mileage             300000.0
# 55763     opel  zafira      4700  2002  with mileage             320000.0
# 56173     opel  zafira      6700  2006  with mileage             293628.0
#
#       fuel_type  volume(cm3)     color transmission         drive_unit
# ...

# %% [markdown]
# Dari data yang ditemukan, terdapat 87 duplikasi data, maka dari itu kami akan melakukan *filtering* atau menghilangkan duplikasi data yang ada

# %%
## Menghapus Duplikat
df_c.drop_duplicates(inplace = True)

# %% [markdown]
# Setelah dihapus maka kami melakukan pengecekan kembali.

# %%
## Ceck Ulang Data Duplikat
df_c[df_c.duplicated()]
# Out:
# Empty DataFrame
# Columns: [make, model, priceUSD, year, condition, mileage(kilometers), fuel_type, volume(cm3), color, transmission, drive_unit]
# Index: []

# %% [markdown]
# Dari hasil yang sudah kami dapatkan, sudah tidak ada data duplikasi dari dataset yangn akan kami olah

# %% [markdown]
# #### **Preview Cleaned Data**

# %% [markdown]
# Setelah semua data sesuai dengan yang akan dianalisa, dibawah ini adalah sampel data yang sudah kami anggap sesuai setelah melewati proses sebelumnya.

# %%
df_c.sample(10)
# Out:
#              make      model  priceUSD  year     condition  \
# 47006     hyundai    solaris     10999  2018  with mileage
# 1535         audi         80       500  1985  with mileage
# 32413    lada-vaz     largus      8350  2017  with mileage
# 6750      peugeot       3008      9500  2010  with mileage
# 54662       volvo       xc90     16000  2008  with mileage
# 42334      nissan  qashqai-2     10800  2009  with mileage
# 38339  volkswagen     passat      4800  2001  with mileage
# 2470        rover        200       700  1992  with mileage
# 55050     citroen      xsara      2390  2001  with mileage
# 4043      peugeot        406      1700  1998  with mileage
#
#        mileage(kilometers) fuel_type  volume(cm3)   color transmission  \
# 47006              10000.0    petrol       1600.0  silver    mechanics
# 1535               22222.0    petrol       1800.0   white    mechanics
# 32413             151000.0    petrol       1600.0    blue    mechanics
# ...

# %% [markdown]
# #### **General Info Cleaned Data**

# %%
dataDesc = []
for i in df_c.columns:
    dataDesc.append([
        i,
        df_c[i].dtypes,
        df_c[i].isna().sum(),
        round(((df_c[i].isna().sum() / len(df_c)) * 100), 2),
        df_c[i].nunique(),
        df_c[i].drop_duplicates().sample(2).values
    ])

pd.DataFrame(dataDesc, columns=[
    "Data Features",
    "Data Types",
    "Null",
    "Null Percentage",
    "Unique",
    "Unique Sample"
])
# Out:
#           Data Features Data Types  Null  Null Percentage  Unique  \
# 0                  make     object     0             0.00      95
# 1                 model     object     0             0.00    1030
# 2              priceUSD      int64     0             0.00    2945
# 3                  year      int64     0             0.00      78
# 4             condition     object     0             0.00       2
# 5   mileage(kilometers)    float64     0             0.00    8364
# 6             fuel_type     object     0             0.00       2
# 7           volume(cm3)    float64     0             0.00     458
# 8                 color     object     0             0.00      13
# 9          transmission     object     0             0.00       2
# 10           drive_unit     object  1852             3.33       4
#
#                         Unique Sample
# 0                [lancia, land-rover]
# 1                     [verona, 100nx]
# 2                       [19949, 7460]
# ...

# %% [markdown]
# **Pengecekan Outlier**

# %%
## Deskripsi Data
df_c.describe()
# Out:
#             priceUSD          year  mileage(kilometers)   volume(cm3)
# count   55656.000000  55656.000000         5.565600e+04  55656.000000
# mean     7448.319534   2003.534444         2.434233e+05   2107.187186
# std      8227.229741      8.103144         3.107229e+05    957.673671
# min        48.000000   1910.000000         0.000000e+00    500.000000
# 25%      2443.000000   1998.000000         1.370000e+05   1600.000000
# 50%      5400.000000   2004.000000         2.280000e+05   1998.000000
# 75%      9900.000000   2010.000000         3.095105e+05   2300.000000
# max    235235.000000   2019.000000         9.999999e+06  20000.000000

# %%
count = 0
fig = plt.figure(figsize=(15,10))

for i in df_c.drop(columns=['make','model','condition','fuel_type','color','transmission','drive_unit']).columns:
    count +=1
    ax= plt.subplot(2,2,count)
    sns.boxplot(df_c[i])
    fig.tight_layout()
    plt.title(i,fontsize=20)

plt.show()

# %%
def find_anomalies(data):
    q1 = data.quantile(0.25)
    q3 = data.quantile(0.75)
    iqr = q3 - q1
    limit = iqr*1.5
    print(f'IQR: {iqr}')

    limit_bawah = q1 - limit
    limit_atas = q3 + limit
    print(f'limit_bawah: {limit_bawah}')
    print(f'limit_atas: {limit_atas}')

# %%
for i in df_c.drop(columns=['make','model','condition','fuel_type','color','transmission','drive_unit']).columns:
    print(i)
    df_anomalies = find_anomalies(df_c[i])
    print(20*('='))
# Out:
# priceUSD
# IQR: 7457.0
# limit_bawah: -8742.5
# limit_atas: 21085.5
# ...
# year
# IQR: 12.0
# limit_bawah: 1980.0
# limit_atas: 2028.0
# ...
# mileage(kilometers)
# IQR: 172510.5
# limit_bawah: -121765.75
# limit_atas: 568276.25
# ...
# volume(cm3)
# IQR: 700.0
# limit_bawah: 550.0
# limit_atas: 3350.0
# ...

# %% [markdown]
# Terdapat outliers pada semua fitur numerikal. Namun hanya untuk data outliers pada fitur `year` yang akan dilakukan rekayasa data karena yang kami akan fokuskan hanya pada mobil di atas 1980, maka untuk data yang di bawah tahun 1980 tidak perlu dimasukan. Dan untuk data outliers di 3 kolom yang lain tidak dihapus dan tetap digunakan untuk analisis berikutnya.

# %%
df['year'].min()
# Out:
# 1910

# %%
df_c = df_c[df_c['year'] >= 1980]

# %%
df_c[df_c['year'] < 1980]
# Out:
# Empty DataFrame
# Columns: [make, model, priceUSD, year, condition, mileage(kilometers), fuel_type, volume(cm3), color, transmission, drive_unit]
# Index: []

# %% [markdown]
# ## **Explanatory Data Analyst**
#
# Selanjutnya kami akan melakukan analisa data

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# 1. Stok produsen mobil dengan jumlah tertinggi (10 teratas).

# %% [markdown]
# ![image.png](attachment:8bb931d8-bd7c-4b93-a08d-699bb0def8ad.png)

# %% [markdown]
# Insight:
#
# Stok unit berdasarkan data yang kami peroleh di Belarus:
#
# - Stok mobil terbanyak yaitu dari produsen volkswagen dengan stok sebanyak 6.802
# - Stok mobil dengan jumlah paling rendah atau sedikit yaitu toyota sebanyak 2.168
#
# Recommendation:
#
# Terdapat beberapa brand yang masih kurang diminati oleh para pengguna mobil namun stok dipasaran sudah  banyak, sehingga untuk divisi pengadaan tidak perlu membeli mobil untuk stok  karena sudah banyak dipasaran. Perusahaan hanya perlu memfokuskan pada stok mobil yang masih belum banyak, namun diminati oleh pangsa pasar.
#
# Action:
#
# Divisi pengadaan perlu membeli untuk stok pada brand:
# - Renault
# - Skoda
# - Hyundai
# - Lada Vasta
# - Kia

# %% [markdown]
# 2. Berapa median harga di pasaran dari brand yang ingin kita beli?

# %% [markdown]
# ![image.png](attachment:56e85f93-8aaa-42e0-bad4-f83232912b01.png)

# %% [markdown]
# Insight:
#
# - Median harga tertinggi yaitu Skoda.
# - Meidan harga terendah yaitu Lada-Vasta
# Recommendation:
#
# Mengutip dari laman (ceicdata.com)[https://www.ceicdata.com/id/indicator/belarus/annual-household-income-per-capita] rata-rata pendapatan perkapita di Belarus 6.698 per tahunnya. Sehingga untuk tim pengadaan barang disarankan membeli stok dengan harga sesuai mangsa pasar.
#
# Action:
#
# Divisi pengadaan barang tidak perlu membeli stok mobil yang tergolong kelas mobil mewah dan perlu melakukan tambahan riset mengenai perkembangan tren merk mobil tiap tahunnya untuk mobil dengan pangsa pasar yang banyak diminati dimana harganya di bawah terjangkau, sehingga lebih cepat perputaran uang pada perusahaan.

# %% [markdown]
# 3. Bagaimana pengaruh kondisi mobil terhadap harga beli?

# %%
df_c = df_c[df_c['condition']!='for parts']

# %%
plt.figure(figsize=(15,10))
plt.subplot(221)
sns.histplot(df_c[df_c['condition']== 'with mileage']["priceUSD"],color='r',kde=True)
plt.title('Distribution of price of condition with mileage')

plt.subplot(222)
sns.histplot(df_c[df_c['condition']== 'with damage']['priceUSD'],color='g',kde=True)
plt.title('Distribution of ages of condition with damage')


plt.subplot(223)
sns.boxplot(data=df_c,y='priceUSD', x='condition')
plt.show()

# %% [markdown]
# Insight:
#
# Untuk kondisi mobil berpengaruh terhadap harga, pada kondisi "with mileage" memiliki harga yang lebih tinggi (100 USD -235235 USD), dibandingkan dengan kondisi "with damage" dengan rentang harga ($95 - $27000)
#
# Recommendation:
#
# Divisi pengadaan barang harus cermat dalam memilih kendaraan yang akan dibeli untuk stok yang akan langsung dijual Kembali, serta memilah jenis kendaraan yang rusak (with damage) yang masih dapat disservice.
#
# Action:
#
# Perusahaan melakukan treatment atau perawatan sesuai dengan kondisi mobil sehingga perusahaan dapat menjual kembali dalam keadaan normal dan menghasilkan profit yang lebih tinggi

# %% [markdown]
# 4. Bagaimana pengaruh tahun produksi terhadap harga jual mobil ?

# %%
plt.figure(figsize=(40,10))

plt.subplot(221)
sns.histplot(df_c[df_c['year']>=1980]["priceUSD"],color='r',kde=True)
plt.title('Distribution of price of year')

plt.subplot(223)
sns.boxplot(data=df_c,y='priceUSD', x='year')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Insight:
#
# Adanya pengaruh tahun terhadap distribusi harga beli, dimana apabila tahun produksi mobil semakin muda maka harga nya semakin bervariasi.
#
# Recommendation:
#
# Perusahaan perlu melakukan sortir atau pemilihan jenis mobil dengan cermat untuk stok. Apabila mendapatkan mobil dengan tahun produksi yang masih muda yang mana harga nya bervariasi ditakutkan terjadinya penambahan stok yang peminatnya sedikit dan harganya terlalu tinggi.
#
# Action:
#
# Perusahaan perlu memiliki sebuah metode atau tools yang membantu untuk menentukan harga beli dengan risiko kesalahan penentuan harga yang rendah seperti machine learning.

# %% [markdown]
# 5. Bagaimana pengaruh jenis bahan bakar terhadap harga jual mobil ?

# %%
df_c= df_c[df_c['fuel_type']!='electrocar']

# %%
plt.figure(figsize=(15,10))

plt.subplot(221)
sns.histplot(df_c[df_c['fuel_type']== 'petrol']["priceUSD"],color='r',kde=True)
plt.title('Distribution of price of fuel type petrol')

plt.subplot(222)
sns.histplot(df_c[df_c['fuel_type']== 'diesel']['priceUSD'],color='g',kde=True)
plt.title('Distribution of ages of fuel type diesel')

plt.subplot(223)
sns.boxplot(data=df_c,y='priceUSD', x='fuel_type')
plt.show()

# %%
df_c[df_c['fuel_type']=='petrol']['priceUSD'].min()
# Out:
# 95

# %%
df_c[df_c['fuel_type']=='petrol']['priceUSD'].max()
# Out:
# 235235

# %%
df_c[df_c['fuel_type']=='diesel']['priceUSD'].min()
# Out:
# 150

# %%
df_c[df_c['fuel_type']=='diesel']['priceUSD'].max()
# Out:
# 111690

# %%
plt.style.use('seaborn')
plt.figure(figsize=(8,7))
plt.pie(df_c['fuel_type'].value_counts().values, 
        autopct='%.2f%%', shadow=True, explode = (0, 0.01), colors=["yellow","green"],textprops={"fontsize":20})
plt.title ('Persentase Stok berdasarkan Jenis Bahan Bakar', size = 30)
plt.legend(df_c['fuel_type'].unique())
plt.show()

# %% [markdown]
# ![image.png](attachment:75bcc436-6cf3-46d8-b78a-baea5482e690.png)

# %% [markdown]
# Insight:
#
# - Jenis bahan bakar petrol memiliki rentang distribusi harga dari $95 - $235235
# - Jenis bahan bakar diesel memiliki rentang distribusi harga dari $150 - $111690
# - Persentase ketersediaan unit stok untuk jenis bahan bakar petrol sebesar 64.55%
# - Persentase ketersediaan unit stok untuk jenis bahan bakar diesel sebesar 35.45%
#
# Dan kami mendapatkan sumber berita dari [rentar.com](https://rentar.com/use-diesel-large-vehicles-rather-petrol/) yang menyatakan bahwa mobil diesel lebih diminati oleh banyak calon pengguna, karena mobil dengan tipe bahan bakar diesel dari segi perawatan lebih mudah dan dari segi konsumsi bahan bakarnya lebih irit atau efisien.
#
# Recommendation:
#
# Kami merekomendasikan untuk perusahaan membeli mobil untuk stok dengan yang lebih banyak pada mobil diesel dikarenakan harganya lebih terjangkau dan perawatannya lebih mudah, namun tetap menyediakan stok untuk bahan bakar petrol.
#
# Action:
#
# Divisi pengadaan barang perlu melakukan riset mengenai tipe tipe mobil diesel ataupun petrol yang saat ini sedang laku di pasaran, sehingga pembelian stok sesuai dengan kebutuhan pasar dengan lebih focus ke mobil berbahan bakar diesel.

# %% [markdown]
# 6. Bagaimana pengaruh jenis transmisi terhadap harga jual mobil ?

# %%
plt.figure(figsize=(15,15))

plt.subplot(221)
sns.histplot(df_c[df_c['transmission']== 'mechanics']["priceUSD"],color='r',kde=True)
plt.title('Distribution of price of Mechanics Transmission')

plt.subplot(222)
sns.histplot(df_c[df_c['transmission']== 'auto']['priceUSD'],color='g',kde=True)
plt.title('Distribution of ages of Automatic Transmission')

plt.subplot(223)
sns.boxplot(data=df_c,y='priceUSD', x='transmission')
plt.show()

# %% [markdown]
# ![image.png](attachment:161cf46a-9e77-45e1-bfa9-62b8d3ed8798.png)

# %%
df_c[df_c['transmission']=='auto']['priceUSD'].min()
# Out:
# 225

# %%
df_c[df_c['transmission']=='auto']['priceUSD'].max()
# Out:
# 235235

# %%
df_c[df_c['transmission']=='mechanics']['priceUSD'].min()
# Out:
# 95

# %%
df_c[df_c['transmission']=='mechanics']['priceUSD'].max()
# Out:
# 80000

# %%
plt.style.use('seaborn')
plt.figure(figsize=(8,7))
plt.pie(df_c['transmission'].value_counts().values, 
        autopct='%.2f%%', explode= (0,0.1), shadow=True,colors=["yellow","green",],textprops={"fontsize":20})
plt.title ('Persentase Stok berdasarkan Jenis Transmisi', size = 30)
plt.legend(df_c['transmission'].unique())
plt.show()

# %% [markdown]
# Insight:
#
# - Jenis mobil dengan transmisi otomatis memiliki distribusi harga dari 224 USD - 235235 USD
# - Jenis mobil dengan transmisi manual / mehcanics memiliki distribusi harga dari 95 USD - 80000 USD
# - Stok mobil dengan jenis transmisi otomatis sebanyak 36.25%
# - Stok mobil dengan jenis transmisi manual sebanyak 63.75%
#
# Recommendation:
#
# Dari hasil insight yang kami dapatkan, perusahaan sebaiknya membeli stok mobil dengan jenis transmisi otomatis karena mengutip dari laman otomoti banyak pengguna mobil yang beralih ke jenis transmisi otomatis dan stok dipasar masih sedikit.
#
# Action:
#
# Untuk divisi pengadaan barang sebaiknya membeli stok berjenis transmisi mobil otomatis agar sesuai dengan kebutuhan pasar namun dengan harga yang masih terjangkau, maka diperlukan riset kembali untuk divisi pengadaan barang.

# %% [markdown]
# 7. Berapa jumlah stok di pasar berdasarkan warna mobil?

# %% [markdown]
# ![image.png](attachment:3dc77111-5650-460b-ad12-095e65b4b92b.png)

# %% [markdown]
# Insight:
#
# - Stok terbanyak di pasar dari data yang kami dapatkan yaitu berwarna Hitam diikuti dengan warna silver dan biru
# - Stok mobil dengan warna paling sedikit adalah warna oranye, kuning dan ungu
#
# Recommendation:
#
# Kami merekomendasikan untuk divisi pengadaan barang membeli stok dengan warna - warna yang menjadi pilihan
# favorit semua orang.
#
# Action:
#
# Divisi pengadaan barang perlu membeli stok dengan warna putih, abu-abu dan kuning dikarenakan berdasarkan hasil riset dari [garasi.id](garasi.id) warna ini banyak diminati dan stok di pasar masih sedikit dibandingkan dengan hitam dan silver.

# %% [markdown]
# 8. Bagaimana sebaran harga stok di pasar berdasarkan warna mobil?

# %%
plt.figure(figsize=(30,15))
plt.subplot(223)
sns.violinplot(data=df_c,y='priceUSD', x='color')
plt.show()

# %% [markdown]
# Insight:
#
# - Warna putih adalah warna mobil dengan ketersediaan dengan sebaran harga tertinggi
# - Warna oranye adalah warna mobil dengan ketersediaan dengan sebaran harga terendah
#
# Recommendation:
#
# Mengutip dari laman [motorbiscuit.com](https://www.motorbiscuit.com/most-popular-car-color-guess-color/) dan [germaincars.com](https://www.germaincars.com/most-popular-car-colors/) bahwa warna yang paling populer adalah
# 1. Putih
# 2. Hitam
# 3. Abu-abu
#
# dari ketiga warna populer diatas perusahaan harus teliti dalam pengadaan barangnya dikarenakan untuk warna favorit sering menawarkan harga yang tinggi dan divisi pengadaan juga harus memperbanyak stok dengan warna favorit tersebut dengan memperhatikan kondisi unitnya.
#
# Action:
#
# - Perusahaan harus melakukan pengadaan barang terhadap jenis warna mobil yang menjadi warna populer seperti warna (putih, kuning dan abu-abu) dan perusahaan harus melihat sebaran harga nya, apabila sebaran harga nya besar maka perusahaan harus memperkecil range harga agar sesuai dengan kemampuan pangsa pasar.

# %% [markdown]
# ## Conclusion
#
# 1. Perlunya pembelian stok pada mobil dengan :
# - Mobil dengan tahun produksi nya <5 tahun dengan harga tidak lebih tinggi diatas rata rata pendapatan perkapita
# - Kondisi yang normal
# - Berjenis bahan bakar diesel
# - Jenis transmisi automatic
# - Berwarna putih, kuning, atau warna yang sedang diminati sesuai perkembangan zaman.
# 2. tidak disarankan membeli pada mobil yang kurang diminati dan stoknya banyak seperti:
# - Mobil berwarna hitam
# - Mobil brand audi, BMW, opel
# - Mobil mewah dengan harga yang tinggi
# 3. Melakukan treatment atau servis terhadap mobil yang terdapat kerusakan sehingga perusahaan dapat menjual dalam keadaan normal dan menghasilkan profit yang lebih tinggi
# 4. Menambahkan beberapa Customer Service yang memiliki hubungan dengan mobil seperti gratis service mesin pada saat pembelian, atau mendapatkan bonus berupa karpet mobil pada saat pembelian unit mobil dengan budget yang tidak perlu terlalu mahal

# %% [markdown]
# ## Recomendation
#
# Before :
# 1. Dalam penentuan harga beli - COGS - harga jual memerlukan tenaga ahli, untuk cost yang dikeluarkan untuk gaji tenaga ahli tersebut sebesar 4370 rubel atau 1729 USD atau Rp. 26.000.000
# 2. Perhitungan masih secara manual menggunakan Microsoft Excel, dimana apabila kedepan stok semakin banyak akan kurang efisien menggunakan metode manual.
#
# After :
# 1. Untuk penghematan cost yang dikeluarkan untuk menggunakan tenaga ahli profesional dimana perhitungan masih secara manual dapat menggantinya dengan machine learning.
# ![WhatsApp Image 2022-06-23 at 14.18.24.jpeg](attachment:e9bedadd-ab13-4cbe-a1d3-3f09343a36b6.jpeg)
# 2. Gaji Data scientist di Belarus 3620 atau 1432 USD Rp. 21.000.000.
#
# **Jika Perusahaan menggunakan Rekomendasi ini**
#    **Pro :**
#         - Perusahaan akan melakukan Reduce Cost dalam 1 bulan 5.000.000 atau jika dilakukan dalam 6 bulan : 6 * 5.000.000 = 30.000.000
#         - Database dapat diakses oleh berbagai divisi jika menggunakan machine learning karena dapat diakses dengan server
#
#    **Cont :**
#         - Dengan tidak merekrut accounting profesional perlu melakukan evaluasi dan upgrading machine learning dengan melakukan riset untuk harga beli-COGS-harga jual agar perekrutan data scientist lebih efisien
#
# source:
# https://gajipokok.com/gaji-tki-di-belarusia/#!

# %%
df_model = df_c.copy()

# %%
# Cek info lebih detail untuk setiap fitur
listItem = []

for col in df_model.columns:
    listItem.append([col, df_model[col].dtype, df_model[col].isna().sum(), round((df_model[col].isna().sum()/len(df_model[col]))*100, 2),
                    df_model[col].nunique(), list(df_model[col].drop_duplicates().sample(2).values)]);

df_model_desc = pd.DataFrame(columns=['dataFeatures', 'dataType', 'null', 'nullPct', 'unique', 'uniqueSample'],
                     data=listItem)
df_model_desc
# Out:
#            dataFeatures dataType  null  nullPct  unique  \
# 0                  make   object     0      0.0      94
# 1                 model   object     0      0.0    1017
# 2              priceUSD    int64     0      0.0    2937
# 3                  year    int64     0      0.0      40
# 4             condition   object     0      0.0       2
# 5   mileage(kilometers)  float64     0      0.0    8340
# 6             fuel_type   object     0      0.0       2
# 7           volume(cm3)  float64     0      0.0     452
# 8                 color   object     0      0.0      13
# 9          transmission   object     0      0.0       2
# 10           drive_unit   object  1827      3.3       4
#
#                          uniqueSample
# 0                 [suzuki, dong-feng]
# 1                  [2363-pikap, 2715]
# 2                       [16637, 6798]
# 3                        [1995, 1983]
# 4         [with damage, with mileage]
# 5                [382933.0, 305333.0]
# ...

# %%
# Missing value heatmap
sns.heatmap(df_model.isnull(), cbar=False);

# %%
# Cek nilai missing value
df_model.isnull().sum()
# Out:
# make                      0
# model                     0
# priceUSD                  0
# year                      0
# condition                 0
# mileage(kilometers)       0
# fuel_type                 0
# volume(cm3)               0
# color                     0
# transmission              0
# drive_unit             1827
# dtype: int64

# %%
df_model.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 55403 entries, 0 to 56243
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   make                 55403 non-null  object
#  1   model                55403 non-null  object
#  2   priceUSD             55403 non-null  int64
#  3   year                 55403 non-null  int64
#  4   condition            55403 non-null  object
#  5   mileage(kilometers)  55403 non-null  float64
#  6   fuel_type            55403 non-null  object
#  7   volume(cm3)          55403 non-null  float64
#  8   color                55403 non-null  object
#  9   transmission         55403 non-null  object
#  10  drive_unit           53576 non-null  object
# dtypes: float64(2), int64(2), object(7)
# memory usage: 7.1+ MB

# %%
df_model['drive_unit'].mode().value_counts()
# Out:
# front-wheel drive    1
# dtype: int64

# %%
df_model['drive_unit'] = df_model['drive_unit'].fillna('front-wheel drive')

# %%
df_model.isna().sum()
# Out:
# make                   0
# model                  0
# priceUSD               0
# year                   0
# condition              0
# mileage(kilometers)    0
# fuel_type              0
# volume(cm3)            0
# color                  0
# transmission           0
# drive_unit             0
# dtype: int64

# %%
count = 0
fig = plt.figure(figsize=(15,10))

for i in df_model.drop(columns=['make','model','condition','fuel_type','color','transmission','drive_unit']).columns:
    count +=1
    ax= plt.subplot(2,2,count)
    sns.boxplot(df_model[i])
    fig.tight_layout()
    plt.title(i,fontsize=20)

plt.show()
